# %%
import pandas as pd

# %%
import glob
print(glob.glob("*.csv"))
# Out:
# ['GDP 666.csv', 'high_school.csv']

# %%
df    = pd.read_table("GDP 666.csv",   
                       encoding = 'utf8',       
                       header = 3,              
                       skiprows = [35,36],      
                       sep =','                
                     )
df
# Out:
#           地区     2015年     2014年     2013年     2012年     2011年     2010年  \
# 0        北京市  23014.59  21330.83  19800.81  17879.40  16251.93  14113.58
# 1        天津市  16538.19  15726.93  14442.01  12893.88  11307.28   9224.46
# 2        河北省  29806.11  29421.15  28442.95  26575.01  24515.76  20394.26
# 3        山西省  12766.49  12761.49  12665.25  12112.83  11237.55   9200.86
# 4     内蒙古自治区  17831.51  17770.19  16916.50  15880.58  14359.88  11672.00
# 5        辽宁省  28669.02  28626.58  27213.22  24846.43  22226.70  18457.27
# 6        吉林省  14063.13  13803.14  13046.40  11939.24  10568.83   8667.58
# 7       黑龙江省  15083.67  15039.38  14454.91  13691.58  12582.00  10368.60
# 8        上海市  25123.45  23567.70  21818.15  20181.72  19195.69  17165.98
# 9        江苏省  70116.38  65088.32  59753.37  54058.22  49110.27  41425.48
# 10       浙江省  42886.49  40173.03  37756.59  34665.33  32318.85  27722.31
# 11       安徽省  22005.63  20848.75  19229.34  17212.05  15300.65  12359.33
# 12       福建省  25979.82  24055.76  21868.49  19701.78  17560.18  14737.12
# 13       江西省  16723.78  15714.63  14410.19  12948.88  11702.82   9451.26
# 14       山东省  63002.33  59426.59  55230.32  50013.24  45361.85  39169.92
# 15       河南省  37002.16  34938.24  32191.30  29599.31  26931.03  23092.36
# 16       湖北省  29550.19  27379.22  24791.83  22250.45  19632.26  15967.61
# 17       湖南省  28902.21  27037.32  24621.67  22154.23  19669.56  16037.96
# 18       广东省  72812.55  67809.85  62474.79  57067.92  53210.28  46013.06
# 19   广西壮族自治区  16803.12  15672.89  14449.90  13035.10  11720.87   9569.85
# 20       海南省   3702.76   3500.72   3177.56   2855.54   2522.66   2064.50
# 21       重庆市  15717.27  14262.60  12783.26  11409.60  10011.37   7925.58
# 22       四川省  30053.10  28536.66  26392.07  23872.80  21026.68  17185.48
# 23       贵州省  10502.56   9266.39   8086.86   6852.20   5701.84   4602.16
# 24       云南省  13619.17  12814.59  11832.31  10309.47   8893.12   7224.18
# 25     西藏自治区   1026.39    920.83    815.67    701.03    605.83    507.46
# 26       陕西省  18021.86  17689.94  16205.45  14453.68  12512.30  10123.48
# 27       甘肃省   6790.32   6836.82   6330.69   5650.20   5020.37   4120.75
# 28       青海省   2417.05   2303.32   2122.06   1893.54   1670.44   1350.43
# 29   宁夏回族自治区   2911.77   2752.10   2577.57   2341.29   2102.21   1689.65
# 30  新疆维吾尔自治区   9324.80   9273.46   8443.84   7505.31   6610.05   5437.47
#
#        2009年     2008年     2007年     2006年
# 0   12153.03  11115.00   9846.81   8117.78
# 1    7521.85   6719.01   5252.76   4462.74
# 2   17235.48  16011.97  13607.32  11467.60
# 3    7358.31   7315.40   6024.45   4878.61
# 4    9740.25   8496.20   6423.18   4944.25
# 5   15212.49  13668.58  11164.30   9304.52
# 6    7278.75   6426.10   5284.69   4275.12
# 7    8587.00   8314.37   7104.00   6211.80
# 8   15046.45  14069.86  12494.01  10572.24
# 9   34457.30  30981.98  26018.48  21742.05
# 10  22990.35  21462.69  18753.73  15718.47
# 11  10062.82   8851.66   7360.92   6112.50
# 12  12236.53  10823.01   9248.53   7583.85
# 13   7655.18   6971.05   5800.25   4820.53
# 14  33896.65  30933.28  25776.91  21900.19
# 15  19480.46  18018.53  15012.46  12362.79
# 16  12961.10  11328.92   9333.40   7617.47
# 17  13059.69  11555.00   9439.60   7688.67
# 18  39482.56  36796.71  31777.01  26587.76
# 19   7759.16   7021.00   5823.41   4746.16
# 20   1654.21   1503.06   1254.17   1065.67
# 21   6530.01   5793.66   4676.13   3907.23
# 22  14151.28  12601.23  10562.39   8690.24
# 23   3912.68   3561.56   2884.11   2338.98
# 24   6169.75   5692.12   4772.52   3988.14
# 25    441.36    394.85    341.43    290.76
# 26   8169.80   7314.58   5757.29   4743.61
# 27   3387.56   3166.82   2703.98   2277.35
# 28   1081.27   1018.62    797.35    648.50
# 29   1353.31   1203.92    919.11    725.90
# 30   4277.05   4183.21   3523.16   3045.26

# %%
df_high_school= pd.read_table("high_school.csv",   
                       encoding = 'utf8',
                       sep =',' )

# %%
df_high_school
# Out:
#           地区  2015年  2014年  2013年  2012年  2011年  2010年  2009年  2008年  2007年  \
# 0        北京市    306    306    291    289    290    289    305    325    328
# 1        天津市    180    181    193    202    209    214    218    221    221
# 2        河北省    578    567    563    565    598    615    661    713    761
# 3        山西省    505    499    504    511    519    534    544    559    569
# 4     内蒙古自治区    284    278    277    272    279    289    306    324    342
# 5        辽宁省    412    415    416    417    422    419    426    435    445
# 6        吉林省    239    240    243    244    248    257    262    278    291
# 7       黑龙江省    377    378    379    398    411    416    430    445    463
# 8        上海市    253    246    243    246    247    261    273    283    309
# 9        江苏省    569    567    578    594    618    653    710    737    781
# 10       浙江省    563    561    569    571    569    569    582    594    603
# 11       安徽省    666    694    698    716    734    743    769    782    779
# 12       福建省    540    542    544    543    559    575    606    610    616
# 13       江西省    460    442    436    435    438    452    476    540    549
# 14       山东省    555    544    547    557    565    592    632    682    750
# 15       河南省    770    774    776    785    792    825    868    908    920
# 16       湖北省    532    541    563    575    585    603    622    655    668
# 17       湖南省    575    580    577    589    594    622    684    742    773
# 18       广东省   1019   1012   1015   1017   1012   1026   1020   1018   1019
# 19   广西壮族自治区    445    445    453    450    446    463    478    493    522
# 20       海南省    106    104    102    103    102    107    108    110    110
# 21       重庆市    261    258    261    262    263    268    267    268    262
# 22       四川省    726    732    735    735    740    747    758    775    806
# 23       贵州省    430    438    448    446    447    444    451    456    485
# 24       云南省    465    446    440    444    444    451    457    460    465
# 25     西藏自治区     30     29     29     30     30     29     24     23     23
# 26       陕西省    488    506    511    530    544    569    586    615    636
# 27       甘肃省    386    402    428    445    436    452    463    480    493
# 28       青海省    101    102    105    109    112    119    126    138    141
# 29   宁夏回族自治区     62     61     62     63     67     70     82     93     97
# 30  新疆维吾尔自治区    357    363    366    366    368    385    413    444    454
#
#     2006年
# 0     335
# 1     231
# 2     801
# 3     589
# 4     359
# 5     470
# 6     296
# 7     475
# 8     317
# 9     838
# 10    611
# 11    786
# 12    636
# 13    587
# 14    787
# 15    955
# 16    689
# 17    800
# 18   1005
# 19    537
# 20    111
# 21    286
# 22    809
# 23    482
# 24    452
# 25     45
# 26    641
# 27    495
# 28    142
# 29    100
# 30    486

# %%
df = df_GDP
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', 'GDP']
df_GDP_done = df_melted
df_GDP_done
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-3a67d8f7ee9c> in <module>()
#       1 df = df_GDP
# ----> 2 df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
#       3 years = [ x for x in df.columns if x!='地区']
#       4 df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
#       5 df_melted.columns = ['地区', '年', 'GDP']
#
# <ipython-input-79-3a67d8f7ee9c> in <listcomp>(.0)
#       1 df = df_GDP
# ----> 2 df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
#       3 years = [ x for x in df.columns if x!='地区']
#       4 df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
#       5 df_melted.columns = ['地区', '年', 'GDP']
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
# 再处理 df_high_school
df = df_high_school
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', '普通高中学校数量']
df_high_school_done = df_melted
df_high_school_done
# Out:
#            地区     年  普通高中学校数量
# 0         北京市  2015       306
# 1         天津市  2015       180
# 2         河北省  2015       578
# 3         山西省  2015       505
# 4      内蒙古自治区  2015       284
# 5         辽宁省  2015       412
# 6         吉林省  2015       239
# 7        黑龙江省  2015       377
# 8         上海市  2015       253
# 9         江苏省  2015       569
# 10        浙江省  2015       563
# 11        安徽省  2015       666
# 12        福建省  2015       540
# 13        江西省  2015       460
# 14        山东省  2015       555
# 15        河南省  2015       770
# 16        湖北省  2015       532
# 17        湖南省  2015       575
# 18        广东省  2015      1019
# 19    广西壮族自治区  2015       445
# 20        海南省  2015       106
# 21        重庆市  2015       261
# 22        四川省  2015       726
# 23        贵州省  2015       430
# 24        云南省  2015       465
# 25      西藏自治区  2015        30
# 26        陕西省  2015       488
# 27        甘肃省  2015       386
# 28        青海省  2015       101
# 29    宁夏回族自治区  2015        62
# ..        ...   ...       ...
# 280       天津市  2006       231
# 281       河北省  2006       801
# 282       山西省  2006       589
# 283    内蒙古自治区  2006       359
# 284       辽宁省  2006       470
# 285       吉林省  2006       296
# 286      黑龙江省  2006       475
# 287       上海市  2006       317
# 288       江苏省  2006       838
# 289       浙江省  2006       611
# 290       安徽省  2006       786
# 291       福建省  2006       636
# 292       江西省  2006       587
# 293       山东省  2006       787
# 294       河南省  2006       955
# 295       湖北省  2006       689
# 296       湖南省  2006       800
# 297       广东省  2006      1005
# 298   广西壮族自治区  2006       537
# 299       海南省  2006       111
# 300       重庆市  2006       286
# 301       四川省  2006       809
# 302       贵州省  2006       482
# 303       云南省  2006       452
# 304     西藏自治区  2006        45
# 305       陕西省  2006       641
# 306       甘肃省  2006       495
# 307       青海省  2006       142
# 308   宁夏回族自治区  2006       100
# 309  新疆维吾尔自治区  2006       486
#
# [310 rows x 3 columns]

# %%
df_p = df_high_school_done.join(df_GDP_done,lsuffix='', rsuffix='_GDP')
df_p
# Out:
#            地区     年  普通高中学校数量    地区_GDP 年_GDP       GDP
# 0         北京市  2015       306       北京市  2015  23014.59
# 1         天津市  2015       180       天津市  2015  16538.19
# 2         河北省  2015       578       河北省  2015  29806.11
# 3         山西省  2015       505       山西省  2015  12766.49
# 4      内蒙古自治区  2015       284    内蒙古自治区  2015  17831.51
# 5         辽宁省  2015       412       辽宁省  2015  28669.02
# 6         吉林省  2015       239       吉林省  2015  14063.13
# 7        黑龙江省  2015       377      黑龙江省  2015  15083.67
# 8         上海市  2015       253       上海市  2015  25123.45
# 9         江苏省  2015       569       江苏省  2015  70116.38
# 10        浙江省  2015       563       浙江省  2015  42886.49
# 11        安徽省  2015       666       安徽省  2015  22005.63
# 12        福建省  2015       540       福建省  2015  25979.82
# 13        江西省  2015       460       江西省  2015  16723.78
# 14        山东省  2015       555       山东省  2015  63002.33
# 15        河南省  2015       770       河南省  2015  37002.16
# 16        湖北省  2015       532       湖北省  2015  29550.19
# 17        湖南省  2015       575       湖南省  2015  28902.21
# 18        广东省  2015      1019       广东省  2015  72812.55
# 19    广西壮族自治区  2015       445   广西壮族自治区  2015  16803.12
# 20        海南省  2015       106       海南省  2015   3702.76
# 21        重庆市  2015       261       重庆市  2015  15717.27
# 22        四川省  2015       726       四川省  2015  30053.10
# 23        贵州省  2015       430       贵州省  2015  10502.56
# 24        云南省  2015       465       云南省  2015  13619.17
# 25      西藏自治区  2015        30     西藏自治区  2015   1026.39
# 26        陕西省  2015       488       陕西省  2015  18021.86
# 27        甘肃省  2015       386       甘肃省  2015   6790.32
# 28        青海省  2015       101       青海省  2015   2417.05
# 29    宁夏回族自治区  2015        62   宁夏回族自治区  2015   2911.77
# ..        ...   ...       ...       ...   ...       ...
# 280       天津市  2006       231       天津市  2006   4462.74
# 281       河北省  2006       801       河北省  2006  11467.60
# 282       山西省  2006       589       山西省  2006   4878.61
# 283    内蒙古自治区  2006       359    内蒙古自治区  2006   4944.25
# 284       辽宁省  2006       470       辽宁省  2006   9304.52
# 285       吉林省  2006       296       吉林省  2006   4275.12
# 286      黑龙江省  2006       475      黑龙江省  2006   6211.80
# 287       上海市  2006       317       上海市  2006  10572.24
# 288       江苏省  2006       838       江苏省  2006  21742.05
# 289       浙江省  2006       611       浙江省  2006  15718.47
# 290       安徽省  2006       786       安徽省  2006   6112.50
# 291       福建省  2006       636       福建省  2006   7583.85
# 292       江西省  2006       587       江西省  2006   4820.53
# 293       山东省  2006       787       山东省  2006  21900.19
# 294       河南省  2006       955       河南省  2006  12362.79
# 295       湖北省  2006       689       湖北省  2006   7617.47
# 296       湖南省  2006       800       湖南省  2006   7688.67
# 297       广东省  2006      1005       广东省  2006  26587.76
# 298   广西壮族自治区  2006       537   广西壮族自治区  2006   4746.16
# 299       海南省  2006       111       海南省  2006   1065.67
# 300       重庆市  2006       286       重庆市  2006   3907.23
# 301       四川省  2006       809       四川省  2006   8690.24
# 302       贵州省  2006       482       贵州省  2006   2338.98
# 303       云南省  2006       452       云南省  2006   3988.14
# 304     西藏自治区  2006        45     西藏自治区  2006    290.76
# 305       陕西省  2006       641       陕西省  2006   4743.61
# 306       甘肃省  2006       495       甘肃省  2006   2277.35
# 307       青海省  2006       142       青海省  2006    648.50
# 308   宁夏回族自治区  2006       100   宁夏回族自治区  2006    725.90
# 309  新疆维吾尔自治区  2006       486  新疆维吾尔自治区  2006   3045.26
#
# [310 rows x 6 columns]

# %%
df_p.drop(["地区_GDP","年_GDP"], axis=1)
# Out:
#            地区     年  普通高中学校数量       GDP
# 0         北京市  2015       306  23014.59
# 1         天津市  2015       180  16538.19
# 2         河北省  2015       578  29806.11
# 3         山西省  2015       505  12766.49
# 4      内蒙古自治区  2015       284  17831.51
# 5         辽宁省  2015       412  28669.02
# 6         吉林省  2015       239  14063.13
# 7        黑龙江省  2015       377  15083.67
# 8         上海市  2015       253  25123.45
# 9         江苏省  2015       569  70116.38
# 10        浙江省  2015       563  42886.49
# 11        安徽省  2015       666  22005.63
# 12        福建省  2015       540  25979.82
# 13        江西省  2015       460  16723.78
# 14        山东省  2015       555  63002.33
# 15        河南省  2015       770  37002.16
# 16        湖北省  2015       532  29550.19
# 17        湖南省  2015       575  28902.21
# 18        广东省  2015      1019  72812.55
# 19    广西壮族自治区  2015       445  16803.12
# 20        海南省  2015       106   3702.76
# 21        重庆市  2015       261  15717.27
# 22        四川省  2015       726  30053.10
# 23        贵州省  2015       430  10502.56
# 24        云南省  2015       465  13619.17
# 25      西藏自治区  2015        30   1026.39
# 26        陕西省  2015       488  18021.86
# 27        甘肃省  2015       386   6790.32
# 28        青海省  2015       101   2417.05
# 29    宁夏回族自治区  2015        62   2911.77
# ..        ...   ...       ...       ...
# 280       天津市  2006       231   4462.74
# 281       河北省  2006       801  11467.60
# 282       山西省  2006       589   4878.61
# 283    内蒙古自治区  2006       359   4944.25
# 284       辽宁省  2006       470   9304.52
# 285       吉林省  2006       296   4275.12
# 286      黑龙江省  2006       475   6211.80
# 287       上海市  2006       317  10572.24
# 288       江苏省  2006       838  21742.05
# 289       浙江省  2006       611  15718.47
# 290       安徽省  2006       786   6112.50
# 291       福建省  2006       636   7583.85
# 292       江西省  2006       587   4820.53
# 293       山东省  2006       787  21900.19
# 294       河南省  2006       955  12362.79
# 295       湖北省  2006       689   7617.47
# 296       湖南省  2006       800   7688.67
# 297       广东省  2006      1005  26587.76
# 298   广西壮族自治区  2006       537   4746.16
# 299       海南省  2006       111   1065.67
# 300       重庆市  2006       286   3907.23
# 301       四川省  2006       809   8690.24
# 302       贵州省  2006       482   2338.98
# 303       云南省  2006       452   3988.14
# 304     西藏自治区  2006        45    290.76
# 305       陕西省  2006       641   4743.61
# 306       甘肃省  2006       495   2277.35
# 307       青海省  2006       142    648.50
# 308   宁夏回族自治区  2006       100    725.90
# 309  新疆维吾尔自治区  2006       486   3045.26
#
# [310 rows x 4 columns]

# %%
df_pp = df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])

# %%
df_pp.query("年==2015")
# Out:
#                普通高中学校数量       GDP
# 地区       年
# 北京市      2015       306  23014.59
# 天津市      2015       180  16538.19
# 河北省      2015       578  29806.11
# 山西省      2015       505  12766.49
# 内蒙古自治区   2015       284  17831.51
# 辽宁省      2015       412  28669.02
# 吉林省      2015       239  14063.13
# 黑龙江省     2015       377  15083.67
# 上海市      2015       253  25123.45
# 江苏省      2015       569  70116.38
# 浙江省      2015       563  42886.49
# 安徽省      2015       666  22005.63
# 福建省      2015       540  25979.82
# 江西省      2015       460  16723.78
# 山东省      2015       555  63002.33
# 河南省      2015       770  37002.16
# 湖北省      2015       532  29550.19
# 湖南省      2015       575  28902.21
# 广东省      2015      1019  72812.55
# 广西壮族自治区  2015       445  16803.12
# 海南省      2015       106   3702.76
# 重庆市      2015       261  15717.27
# 四川省      2015       726  30053.10
# 贵州省      2015       430  10502.56
# 云南省      2015       465  13619.17
# 西藏自治区    2015        30   1026.39
# 陕西省      2015       488  18021.86
# 甘肃省      2015       386   6790.32
# 青海省      2015       101   2417.05
# 宁夏回族自治区  2015        62   2911.77
# 新疆维吾尔自治区 2015       357   9324.80

# %%
# %matplotlib inline
df_pp.query("年==2015").plot(kind='scatter', x='普通高中学校数量', y='GDP', 
          title = '普通高中学校数量与GDP的关系：分省数据')

# %%
# 解决中文乱码问题
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

df_plot = df_pp.query("年==2015")
df_plot.plot(kind='scatter', x='普通高中学校数量', y='GDP', 
          title = '普通高中学校数量与GDP的关系：分省数据')

# %%
# Regression Using Pandas and Statsmodels
import numpy as np
fit = np.polyfit(x=df_pp.query("年==2015")['普通高中学校数量'], y=df_pp.query("年==2015")['GDP'], deg=1)

# %%
x=df_plot['普通高中学校数量']
y=df_plot['GDP']
ax = df_plot.plot(kind='scatter', x='普通高中学校数量', y='GDP', 
          title = '普通高中学校数量与GDP的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='yellow')
ax.scatter(x, y)

# %%
df_pp
# Out:
#                普通高中学校数量       GDP
# 地区       年
# 北京市      2015       306  23014.59
# 天津市      2015       180  16538.19
# 河北省      2015       578  29806.11
# 山西省      2015       505  12766.49
# 内蒙古自治区   2015       284  17831.51
# 辽宁省      2015       412  28669.02
# 吉林省      2015       239  14063.13
# 黑龙江省     2015       377  15083.67
# 上海市      2015       253  25123.45
# 江苏省      2015       569  70116.38
# 浙江省      2015       563  42886.49
# 安徽省      2015       666  22005.63
# 福建省      2015       540  25979.82
# 江西省      2015       460  16723.78
# 山东省      2015       555  63002.33
# 河南省      2015       770  37002.16
# 湖北省      2015       532  29550.19
# 湖南省      2015       575  28902.21
# 广东省      2015      1019  72812.55
# 广西壮族自治区  2015       445  16803.12
# 海南省      2015       106   3702.76
# 重庆市      2015       261  15717.27
# 四川省      2015       726  30053.10
# 贵州省      2015       430  10502.56
# 云南省      2015       465  13619.17
# 西藏自治区    2015        30   1026.39
# 陕西省      2015       488  18021.86
# 甘肃省      2015       386   6790.32
# 青海省      2015       101   2417.05
# 宁夏回族自治区  2015        62   2911.77
# ...                 ...       ...
# 天津市      2006       231   4462.74
# 河北省      2006       801  11467.60
# 山西省      2006       589   4878.61
# 内蒙古自治区   2006       359   4944.25
# 辽宁省      2006       470   9304.52
# 吉林省      2006       296   4275.12
# 黑龙江省     2006       475   6211.80
# 上海市      2006       317  10572.24
# 江苏省      2006       838  21742.05
# 浙江省      2006       611  15718.47
# 安徽省      2006       786   6112.50
# 福建省      2006       636   7583.85
# 江西省      2006       587   4820.53
# 山东省      2006       787  21900.19
# 河南省      2006       955  12362.79
# 湖北省      2006       689   7617.47
# 湖南省      2006       800   7688.67
# 广东省      2006      1005  26587.76
# 广西壮族自治区  2006       537   4746.16
# 海南省      2006       111   1065.67
# 重庆市      2006       286   3907.23
# 四川省      2006       809   8690.24
# 贵州省      2006       482   2338.98
# 云南省      2006       452   3988.14
# 西藏自治区    2006        45    290.76
# 陕西省      2006       641   4743.61
# 甘肃省      2006       495   2277.35
# 青海省      2006       142    648.50
# 宁夏回族自治区  2006       100    725.90
# 新疆维吾尔自治区 2006       486   3045.26
#
# [310 rows x 2 columns]

# %%
# tooltip 工具提示 
df_pp['desc'] = df_pp.index.get_level_values(0)

# %%
# 制图
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = '普通高中学校数量：个数' 
ylabel = 'GDP：产值'

hover = HoverTool(
    tooltips=[
        ( '个数',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_pp.query("年==2015")

fig.circle("普通高中学校数量", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 30)

#regression line
xs = [min(df_plot["普通高中学校数量"]), max(df_plot["普通高中学校数量"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
# D:\jupyter\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning: ResizeTool is removed in Bokeh 0.12.7, adding it is a no-op. In the future, accessing ResizeTool will be an error
#   warn(message)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dd6d4249-8c70-4ddf-b148-9d5fbcf10ad4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="89572006-14ee-4bf2-a20b-bbb23a659b2a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("89572006-14ee-4bf2-a20b-bbb23a659b2a");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("89572006-14ee-4bf2-a20b-bbb23a659b2a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '89572006-14ee-4bf2-a20b-bbb23a659b2a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b1db2999-2715-40b5-ac9b-24bd17b70846":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":30},"x":{"field":"\u666e\u901a\u9ad8\u4e2d\u5b66\u6821\u6570\u91cf"},"y":{"field":"GDP"}},"id":"f0e91a57-11f8-4e2d-854b-c335f97c0dd1","type":"Circle"},{"attributes":{"callback":null},"id":"9eb5320d-a2d6-4d18-84eb-41941750af97","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5a153c88-8df1-4390-8544-f4f6b274f938","type":"Line"},{"attributes":{"data_source":{"id":"5677b425-7544-4582-ad23-bd05a85db94b","type":"ColumnDataSource"},"glyph":{"id":"6ebce951-3b82-4a06-a647-db3854c51c03","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5a153c88-8df1-4390-8544-f4f6b274f938","type":"Line"},"selection_glyph":null,"view":{"id":"85541e43-2b4b-4c7a-b34f-0099a65a5b34","type":"CDSView"}},"id":"f093cc7a-4831-4242-ae88-6ed5888deefb","type":"GlyphRenderer"},{"attributes":{"source":{"id":"66f38009-cbd1-43cb-9eab-2234b2e0fc31","type":"ColumnDataSource"}},"id":"43cdc759-3ab5-4659-9a94-bfad1d87d6a3","type":"CDSView"},{"attributes":{"plot":{"id":"6e30bf28-9944-4b87-86c6-483280dec06b","subtype":"Figure","type":"Plot"},"ticker":{"id":"03be4e23-c538-4cdf-bf4e-c213f9e5ac25","type":"BasicTicker"}},"id":"1269fd69-056b-4291-b355-7b2a576e6434","type":"Grid"},{"attributes":{"axis_label":"GDP\uff1a\u4ea7\u503c","formatter":{"id":"add42bc5-a26a-4572-be89-6fddcf419c22","type":"BasicTickFormatter"},"plot":{"id":"6e30bf28-9944-4b87-86c6-483280dec06b","subtype":"Figure","type":"Plot"},"ticker":{"id":"7feb6c26-4d5b-4fb6-b518-cdd29e588ecb","type":"BasicTicker"}},"id":"c7e7dfdd-f1ec-46b3-85bf-882626e7f836","type":"LinearAxis"},{"attributes":{},"id":"03df9f9b-7c52-4077-bf5f-609d05d47b38","type":"LinearScale"},{"attributes":{},"id":"a362fb5d-f3d5-475e-aa94-59d873b92f4c","type":"BasicTickFormatter"},{"attributes":{},"id":"7feb6c26-4d5b-4fb6-b518-cdd29e588ecb","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ebce951-3b82-4a06-a647-db3854c51c03","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"6e30bf28-9944-4b87-86c6-483280dec06b","subtype":"Figure","type":"Plot"},"ticker":{"id":"7feb6c26-4d5b-4fb6-b518-cdd29e588ecb","type":"BasicTicker"}},"id":"9f9d10ab-7f82-41b4-b46c-be4dd3826ace","type":"Grid"},{"attributes":{"callback":null,"column_names":["\u666e\u901a\u9ad8\u4e2d\u5b66\u6821\u6570\u91cf","GDP","desc","\u5730\u533a_\u5e74"],"data":{"GDP":{"__ndarray__":"","dtype":"float64","shape":[31]},"desc":["\u5317\u4eac\u5e02","\u5929\u6d25\u5e02","\u6cb3\u5317\u7701","\u5c71\u897f\u7701","\u5185\u8499\u53e4\u81ea\u6cbb\u533a","\u8fbd\u5b81\u7701","\u5409\u6797\u7701","\u9ed1\u9f99\u6c5f\u7701","\u4e0a\u6d77\u5e02","\u6c5f\u82cf\u7701","\u6d59\u6c5f\u7701","\u5b89\u5fbd\u7701","\u798f\u5efa\u7701","\u6c5f\u897f\u7701","\u5c71\u4e1c\u7701","\u6cb3\u5357\u7701","\u6e56\u5317\u7701","\u6e56\u5357\u7701","\u5e7f\u4e1c\u7701","\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a","\u6d77\u5357\u7701","\u91cd\u5e86\u5e02","\u56db\u5ddd\u7701","\u8d35\u5dde\u7701","\u4e91\u5357\u7701","\u897f\u85cf\u81ea\u6cbb\u533a","\u9655\u897f\u7701","\u7518\u8083\u7701","\u9752\u6d77\u7701","\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a","\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a"],"\u5730\u533a_\u5e74":[["\u5317\u4eac\u5e02",2015],["\u5929\u6d25\u5e02",2015],["\u6cb3\u5317\u7701",2015],["\u5c71\u897f\u7701",2015],["\u5185\u8499\u53e4\u81ea\u6cbb\u533a",2015],["\u ...

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = '普通高中学校数量：个数' 
ylabel = 'GDP：产值大小'
hover = HoverTool(
    tooltips=[
        ( '个数大小',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_pp.index.get_level_values(1).min()
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("普通高中学校数量", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_pp.query("年=={yr}".format(yr=year))
    plt.data_source.data['普通高中学校数量'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['普通高中学校数量']].iloc[:,0].values)
    plt.data_source.data['GDP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['GDP']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_pp.index.get_level_values(1).min(), 
                end=df_pp.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
# D:\jupyter\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning: ResizeTool is removed in Bokeh 0.12.7, adding it is a no-op. In the future, accessing ResizeTool will be an error
#   warn(message)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2f2f49e9-f084-4119-8e53-b8d6f8181cc5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e560d06-b7ea-4b19-bae8-6fb295105396"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6e560d06-b7ea-4b19-bae8-6fb295105396");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e560d06-b7ea-4b19-bae8-6fb295105396");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e560d06-b7ea-4b19-bae8-6fb295105396' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf9c9b10-008b-4d16-b665-9e6eef6dd944":{"roots":{"references":[{"attributes":{},"id":"9250a08f-3744-4568-92d8-d532d0e36421","type":"LinearScale"},{"attributes":{"plot":{"id":"55ee89af-36da-49f2-a3e7-fa447c218055","subtype":"Figure","type":"Plot"},"ticker":{"id":"658d9bb2-7331-4ff5-9aca-3623c953544e","type":"BasicTicker"}},"id":"cea4b959-0790-4199-97db-5631577a5c7f","type":"Grid"},{"attributes":{"axis_label":"\u666e\u901a\u9ad8\u4e2d\u5b66\u6821\u6570\u91cf\uff1a\u4e2a\u6570","formatter":{"id":"affe3b0a-98da-47db-b113-514df1ced810","type":"BasicTickFormatter"},"plot":{"id":"55ee89af-36da-49f2-a3e7-fa447c218055","subtype":"Figure","type":"Plot"},"ticker":{"id":"658d9bb2-7331-4ff5-9aca-3623c953544e","type":"BasicTicker"}},"id":"8897adb1-a606-4920-9edf-e67ba831ac1d","type":"LinearAxis"},{"attributes":{},"id":"affe3b0a-98da-47db-b113-514df1ced810","type":"BasicTickFormatter"},{"attributes":{},"id":"658d9bb2-7331-4ff5-9aca-3623c953544e","type":"BasicTicker"},{"attributes":{"axis_label":"GDP\uff1a\u4ea7\u503c\u5927\u5c0f","formatter":{"id":"77364168-4aa1-4855-9d95-f6ec0f56aecd","type":"BasicTickFormatter"},"plot":{"id":"55ee89af-36da-49f2-a3e7-fa447c218055","subtype":"Figure","type":"Plot"},"ticker":{"id":"a398cc3a-5e72-4efc-9562-a2c5f3a7ee25","type":"BasicTicker"}},"id":"3b519c8b-8016-4b64-8c82-e4308a067985","type":"LinearAxis"},{"attributes":{},"id":"a398cc3a-5e72-4efc-9562-a2c5f3a7ee25","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"\u666e\u901a\u9ad8\u4e2d\u5b66\u6821\u6570\u91cf"},"y":{"field":"GDP"}},"id":"a0bc3f12-be1a-4988-b510-aefc0b71ab00","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"55ee89af-36da-49f2-a3e7-fa447c218055","subtype":"Figure","type":"Plot"},"ticker":{"id":"a398cc3a-5e72-4efc-9562-a2c5f3a7ee25","type":"BasicTicker"}},"id":"7480d199-e1d8-494c-800f-f2415bf52c00","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"\u666e\u901a\u9ad8\u4e2d\u5b66\u6821\u6570\u91cf"},"y":{"field":"GDP"}},"id":"8a2cf573-6e4f-4ad7-b463-1dfa93cdb79a","type":"Circle"},{"attributes":{"callback":null,"tooltips":[["\u4e2a\u6570\u5927\u5c0f","$x{0,F}"],["\u4ea7\u503c\u5927\u5c0f","$y{0,F}"],["\u5730\u533a","@desc"]]},"id":"eee6ab88-caef-4346-ab8b-15f7b3fcee44","type":"HoverTool"},{"attributes":{"code":"\nif (IPython.notebook.kernel !== undefined) {\n    var kernel = IPython.notebook.kernel;\n    cmd = \"update_plot(\" + cb_obj.value + \")\";\n    kernel.execute(cmd, {}, {});\n}\n"},"id":"7b43b7cf-dc65-4d26-8aa9-f37946f9efa8","type":"CustomJS"},{"attributes":{},"id":"77364168-4aa1-4855-9d95-f6ec0f56aecd","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"3e420241-6976-4463-92bd-2462e29202a3","type":"ColumnDataSource"},"glyph":{"id":"a0bc3f12-be1a-4988-b510-aefc0b71ab00","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8a2cf573-6e4f-4ad7-b463-1dfa93cdb79a","type":"Circle"},"selection_glyph":null,"view":{"id":"ea10bc64-e272-4e51-ae91-028a780deb74","type":"CDSView"}},"id":"02f2a09c-c639-4a8b-9257-039aea035bdf","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"67ba4b12-be8f-4ca8-8986-a107ddca6f32","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"c265fa56-f67b-4cab-907b-d9525b25d6f8","type":"Slider"}]},"id":"60b34f0d-25f7-46df-acbc-8fda12049a83","type":"WidgetBox"},{"attributes":{},"id":"e9d91625-e305-43fb-b368-7ca9468cf075","type":"PanTool"},{"attributes":{"below":[{"id":"8897adb1- ...
